# %%
import numpy as np
from utils import estimate_privacy_risk

# %%
# Example signals from a GAN trained on ChestMNIST

member_signals = np.load("signal_values/train_signals.npy")
non_member_signals = np.load("signal_values/test_signals.npy")
population_signals = np.load("signal_values/population_signals.npy")

# %%
results = estimate_privacy_risk(
    population_signals,
    member_signals,
    non_member_signals,
    show_roc=True,
    log_axis=True,
)
